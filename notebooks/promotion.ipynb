# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,OneHotEncoder,OrdinalEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error

# %%
df = pd.read_csv('k12_dataset.csv')

# %%
df
# Out:
#               name  age  gender country        state        city  \
# 0        Student_1   13  Female   India    Karnataka       Hubli
# 1        Student_2   11    Male   India    Karnataka      Mysore
# 2        Student_3   13    Male   India   Tamil Nadu     Chennai
# 3        Student_4   11  Female   India    Karnataka   Bangalore
# 4        Student_5    8  Female   India   Tamil Nadu  Coimbatore
# ...            ...  ...     ...     ...          ...         ...
# 8995  Student_8996   11  Female   India    Karnataka       Hubli
# 8996  Student_8997    6    Male   India  West Bengal      Howrah
# 8997  Student_8998   15  Female   India  West Bengal     Kolkata
# 8998  Student_8999   10  Female   India  Maharashtra      Mumbai
# 8999  Student_9000   16    Male   India        Delhi  Karol Bagh
#
#      parent_occupation earning_class level_of_student level_of_course  \
# 0       Government Job          High         Advanced    Intermediate
# 1             Business        Middle         Advanced           Basic
# 2             Business        Middle     Intermediate           Basic
# 3               Doctor        Middle         Beginner    Intermediate
# 4               Doctor           Low         Beginner           Basic
# ...                ...           ...              ...             ...
# 8995             Other          High     Intermediate        Advanced
# 8996           Teacher          High         Beginner           Basic
# 8997           Teacher          High         Beginner           Basic
# 8998          Engineer           Low     Intermediate    Intermediate
# 8999           Teacher          High     Intermediate    Intermediate
#
#      course_name  time_spent_per_day    material_name material_level  \
# 0           Java                4.14            Tutor           Easy
# 1            C++                5.25            Tutor           Hard
# 2            C++                4.80              PDF         Medium
# 3            C++                5.35              PDF         Medium
# 4     JavaScript                3.42  Online Learning         Medium
# ...          ...                 ...              ...            ...
# 8995      Python                5.71            Tutor           Easy
# 8996         SQL                6.65             Book           Easy
# 8997        Java                5.90              PDF           Easy
# 8998         C++                3.77          College           Hard
# 8999        Java                4.04              PDF           Hard
#
#       iq_of_student  assessment_score promoted_or_skipped
# 0                82                87            Promoted
# 1               149               100            Promoted
# 2                95                79            Promoted
# 3               115                94            Promoted
# 4               148               100            Promoted
# ...             ...               ...                 ...
# 8995            111                88            Promoted
# 8996            150               100            Promoted
# 8997             85                87            Promoted
# 8998            122                86            Promoted
# 8999            106                81            Promoted
#
# [9000 rows x 17 columns]

# %%
df.drop(['name',  'country', 'state', 'city'], axis=1, inplace=True)

# %%
df
# Out:
#       age  gender parent_occupation earning_class level_of_student  \
# 0      13  Female    Government Job          High         Advanced
# 1      11    Male          Business        Middle         Advanced
# 2      13    Male          Business        Middle     Intermediate
# 3      11  Female            Doctor        Middle         Beginner
# 4       8  Female            Doctor           Low         Beginner
# ...   ...     ...               ...           ...              ...
# 8995   11  Female             Other          High     Intermediate
# 8996    6    Male           Teacher          High         Beginner
# 8997   15  Female           Teacher          High         Beginner
# 8998   10  Female          Engineer           Low     Intermediate
# 8999   16    Male           Teacher          High     Intermediate
#
#      level_of_course course_name  time_spent_per_day    material_name  \
# 0       Intermediate        Java                4.14            Tutor
# 1              Basic         C++                5.25            Tutor
# 2              Basic         C++                4.80              PDF
# 3       Intermediate         C++                5.35              PDF
# 4              Basic  JavaScript                3.42  Online Learning
# ...              ...         ...                 ...              ...
# 8995        Advanced      Python                5.71            Tutor
# 8996           Basic         SQL                6.65             Book
# 8997           Basic        Java                5.90              PDF
# 8998    Intermediate         C++                3.77          College
# 8999    Intermediate        Java                4.04              PDF
#
#      material_level  iq_of_student  assessment_score promoted_or_skipped
# 0              Easy             82                87            Promoted
# 1              Hard            149               100            Promoted
# 2            Medium             95                79            Promoted
# 3            Medium            115                94            Promoted
# 4            Medium            148               100            Promoted
# ...             ...            ...               ...                 ...
# 8995           Easy            111                88            Promoted
# 8996           Easy            150               100            Promoted
# 8997           Easy             85                87            Promoted
# 8998           Hard            122                86            Promoted
# 8999           Hard            106                81            Promoted
#
# [9000 rows x 13 columns]

# %%
df.sample(10)
# Out:
#       age  gender parent_occupation earning_class level_of_student  \
# 4382   14  Female          Business        Middle         Advanced
# 6636    6  Female          Engineer           Low     Intermediate
# 3350   17    Male             Other           Low         Beginner
# 3951    6  Female    Government Job        Middle     Intermediate
# 5478   17    Male            Doctor        Middle         Advanced
# 8170   12    Male            Doctor        Middle     Intermediate
# 7720   12    Male           Teacher           Low         Beginner
# 8896   12  Female          Engineer        Middle     Intermediate
# 3242   15  Female            Doctor        Middle         Advanced
# 189     7  Female    Government Job           Low     Intermediate
#
#      level_of_course course_name  time_spent_per_day material_name  \
# 4382    Intermediate         SQL                5.51          Book
# 6636        Advanced        Java                5.70          Book
# 3350    Intermediate  JavaScript                4.66           PDF
# 3951        Advanced  JavaScript                5.64       College
# 5478        Advanced        Java                5.55       College
# 8170        Advanced        Java                4.61           PDF
# 7720    Intermediate         SQL                3.93         Tutor
# 8896        Advanced        Java                5.16           PDF
# 3242           Basic         SQL                4.79           PDF
# 189     Intermediate        Java                6.27          Book
#
#      material_level  iq_of_student  assessment_score promoted_or_skipped
# 4382         Medium            135                96            Promoted
# 6636         Medium            149               100            Promoted
# 3350           Easy            132                95            Promoted
# 3951         Medium            145                92            Promoted
# 5478           Easy            105                89            Promoted
# 8170           Easy            112                86            Promoted
# 7720         Medium            143                89            Promoted
# 8896           Easy            159                99            Promoted
# 3242         Medium            147                95            Promoted
# 189          Medium            109                94            Promoted

# %%
ohe_features = ['gender', 'parent_occupation', 'course_name', 'material_name']
ordinal_features = ['earning_class', 'level_of_student', 'level_of_course', 'material_level']
target_column = 'promoted_or_skipped'  # Target column for label encoding

# Label encode the target variable
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)  # Encode target variable

# Define the ColumnTransformer with encoding and scaling
preprocessor = ColumnTransformer(
    transformers=[
        ('ohe', OneHotEncoder(handle_unknown='ignore'), ohe_features),
        ('ordinal', OrdinalEncoder(), ordinal_features),
     
        # Apply scaling to ordinal features only
    ],
    remainder='passthrough'  # Keep any remaining numerical columns
)

# Create a pipeline with preprocessing and a RandomForestClassifier model
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    
    ('classifier', RandomForestClassifier(n_estimators=300, max_depth=20, random_state=42))
])

# %%
x = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
pipeline.fit(x_train, y_train)
# Out:
# c:\Users\Asus\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\compose\_column_transformer.py:1624: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['gender',
#                                                    'parent_occupation',
#                                                    'course_name',
#                                                    'material_name']),
#                                                  ('ordinal', OrdinalEncoder(),
#                                                   ['earning_class',
#                                                    'level_of_student',
#                                                    'level_of_course',
#                                                    'material_level'])])),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=20, n_estimators=300,
#                                         random_state=42))])

# %%
y_pred = pipeline.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 1.0

# %%
feature_names = ['age','gender','parent_occupation', 'earning_class',
                 'level_of_student', 'level_of_course', 'course_name',
                 'time_spent_per_day', 'material_name', 'material_level',
                 'iq_of_student','assessment_score']

# Given input data
sample_input = np.array([[13, 'Female', 'Government Job', 'High', 
                          'Advanced', 'Intermediate', 'Java', 
                          4.14, 'Tutor', 'Easy', 82,87]])

# Convert input to a DataFrame
sample_df = pd.DataFrame(sample_input, columns=feature_names)

# Predict using trained pipeline
predicted_result = pipeline.predict(sample_df)

# Print the prediction
print("Result:", predicted_result[0])
# Out:
# Result: Promoted

# %%
# import pickle
# with open("Promotion.pkl", "wb") as file:
#      pickle.dump(pipeline, file)
